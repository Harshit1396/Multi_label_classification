# %% [markdown]
# **Loading saved dataset**

# %%
import pickle
import pandas as pd 
movies_new = pd.read_pickle('my_df.pickle')

movies_new.drop(['plot','genre'],axis=1)
# Out:
#        movie_id  ...                                         clean_plot
# 0      23890098  ...  shlykov hard working taxi driver lyosha saxoph...
# 1      31186339  ...  nation panem consists wealthy capitol twelve p...
# 2      20663735  ...  poovalli induchoodan sentenced six years priso...
# 3       2231378  ...  lemon drop kid new york city swindler illegall...
# 4        595909  ...  seventh day adventist church pastor michael ch...
# 5       5272176  ...  president way give speech traveling man shows ...
# 6       1952976  ...  plot film opens young girl dahlia stands outsi...
# 7      24225279  ...  story begins hannah young jewish teen completi...
# 8       2462689  ...  infuriated told write one final column laid ne...
# 9      20532852  ...  line people drool window shop market butcher b...
# 10     15401493  ...  lola attempts gain fathers trust fund hiring h...
# 11     18188932  ...  milan goran two criminals smuggle illegal immi...
# 12      2940516  ...  bumbling pirate crewman kills captain learning...
# 13      1335380  ...  film based events happened ship exodus well ev...
# 14      1480747  ...  plot following sudden death kids father pop lo...
# 15     24448645  ...  despite lucys reservations agrees husband requ...
# 16     15072401  ...  alan colby heir vast fortune reappears seven y...
# 17      4018288  ...  debbies favorite band dream street favorite me...
# 18      4596602  ...  ashes ashes set london england film surreal jo...
# 19     15224586  ...  film follows experience vietnamese refugees un...
# 20     15585766  ...  three friends droving cattle australia restles...
# 21      1760737  ...  set lonely city rainy night film takes place b...
# 22     29062594  ...  group teenagers catholic boarding school provi...
# 23     29326153  ...  film follows lives several west point cadet cl...
# 24      9252321  ...  story zulu family composite story events enact...
# 25      8388648  ...  film opens madhav sreenu playing football cup ...
# 27     13455076  ...  stooges play three sets identical triplets bor...
# 28     33269085  ...  ranchhod rai patel egotistical arrogant self m...
# 29      2254491  ...  preetam struggling cartoonist meets anita tenn...
# 30       447194  ...  samson hebrew placed nazirite vows birth mothe...
# ...         ...  ...                                                ...
# 42174    277160  ...  virginia gin baker investigator waverly insura...
# 42175  36057885  ...  raghu prabhu womaniser married lakshmi raghu w...
# 42176  12118772  ...  kidstuff asked police investigate case interna...
# 42177  20402406  ...  th century three women accused witchcraft hang...
# 42178  24327307  ...  mythological film features antics child krishn...
# 42179  27858729  ...  count vertigo hires merlyn assassinate princes...
# 42180  17736697  ...  paula eastman hollywood actress alcohol proble...
# 42181  22762373  ...  sakthi spoiled rich kid mother sachu grandfath...
# 42182  29380772  ...  music group go stay childhood home manager hau...
# 42183   8355009  ...  movie features pro ch vez anti ch vez militant...
# 42184   1585815  ...  first half film told non consecutive narrative...
# 42185    677389  ...  dr sullivan travis wealthy dallas gynecologist...
# 42186   8605430  ...  story develops around evolution titli girl wom...
# 42187  27978238  ...  union army officer capt john hayes asked take ...
# 42188  21972773  ...  film revolves around nandhan lankan youth kidn...
# 42189  25758881  ...  story set late follows los angeles cop michael...
# 42190   4913923  ...  northern norway little girl named dina acciden...
# 42191  24318106  ...  samy brahmin boy friend karuna grow slums roya...
# 42192  11957333  ...  clarence mumford robitussin addict living pare...
# 42193  26261438  ...  drinking alone one night reminiscing previous ...
# 42194    871575  ...  plot alternate universe people addicted illega...
# 42195  17208834  ...  high school prom georgia unexpectedly interrup...
# 42196  29046736  ...  lucy working dancer sleazy strip joint stage a...
# 42197  30352708  ...  twenty something eun mo listens taxi driver dr...
# 42198   2867597  ...  attempt bring famed mr bill clay characters li...
# 42199  34808485  ...  story reema young muslim schoolgirl malabar lo...
# 42200   1096473  ...  hollywood director leo andreyev looks photogra...
# 42201  35102018  ...  american luthier focuses randy parsons transfo...
# 42202   8628195  ...  abdur rehman khan middle aged dry fruit seller...
# 42203   6040782  ...  operation dynamo taken place newly conquered f...
#
# [41793 rows x 4 columns]

# %% [markdown]
# **Dataset transformation for model fitting**

# %%
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

multilabel_binarizer = MultiLabelBinarizer()
multilabel_binarizer.fit(movies_new['genre_new'])

#Transform target variable 
#One hot encoding for multilabel 
y = multilabel_binarizer.transform(movies_new['genre_new'])

# %%
tfidf_vectorizer = TfidfVectorizer(max_df=0.7, max_features=5000)

# %%
xtrain, xval, ytrain, yval = train_test_split(movies_new['clean_plot'], y, test_size=0.2, random_state=9)

xtrain_tfidf = tfidf_vectorizer.fit_transform(xtrain)
xval_tfidf = tfidf_vectorizer.transform(xval)

# %%
from sklearn.linear_model import LogisticRegression

# Binary Relevance
from sklearn.multiclass import OneVsRestClassifier

# Performance metric
from sklearn.metrics import f1_score

# %%
lr = LogisticRegression(solver='liblinear')
clf = OneVsRestClassifier(lr)

# %%
# Fit model on train data
clf.fit(xtrain_tfidf, ytrain)
# Out:
# OneVsRestClassifier(estimator=LogisticRegression(C=1.0, class_weight=None,
#                                                  dual=False, fit_intercept=True,
#                                                  intercept_scaling=1,
#                                                  l1_ratio=None, max_iter=100,
#                                                  multi_class='warn',
#                                                  n_jobs=None, penalty='l2',
#                                                  random_state=None,
#                                                  solver='liblinear', tol=0.0001,
#                                                  verbose=0, warm_start=False),
#                     n_jobs=None)

# %% [markdown]
# **Evaluation metrics**

# %%
#Evaluation metric:
y_pred = clf.predict(xval_tfidf)
print('Logistic Regression score: ',f1_score(yval, y_pred, average="micro"))

y_pred_prob = clf.predict_proba(xval_tfidf)
t = 0.3 # threshold value
y_pred_new = (y_pred_prob >= t).astype(int)
print('Logistic Regression score with thershold 0.3: ',f1_score(yval, y_pred_new, average="micro"))
# Out:
# Logistic Regression score:  0.529327981354396
# Logistic Regression score with thershold 0.3:  0.6035600795721704

# %%
from sklearn.metrics import hamming_loss
print('Hamming loss',hamming_loss(yval,y_pred))
# Out:
# Hamming loss 0.025671519953836302

# %%
import re

# %%
def clean_text(text):
    # remove backslash-apostrophe 
    text = re.sub("\'", "", text) 
    # remove everything except alphabets 
    text = re.sub("[^a-zA-Z]"," ",text) 
    # remove whitespaces 
    text = ' '.join(text.split()) 
    # convert text to lowercase 
    text = text.lower() 
    
    return text

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

#Function to remove stopwords
def remove_stopwords(text):
    no_stopword_text = [w for w in text.split() if not w in stop_words]
    return ' '.join(no_stopword_text)

# %% [markdown]
# **Affine clustering prediction**

# %%
aux=pd.read_pickle('Clusterform.pickle')

# %%
#Predicting and displaying tags for first 100 datasets in validation set
def infer_tags(q):
    q = clean_text(q)
    q = remove_stopwords(q)
    q_vec = tfidf_vectorizer.transform([q])
    q_pred = clf.predict(q_vec)
    return multilabel_binarizer.inverse_transform(q_pred)
  
  
for i in range(10): 
  k = xval.sample(1).index[0] 
  print("Movie: ", movies_new['movie_name'][k], "\nPredicted genre: ", infer_tags(xval[k])), print("Actual genre: ",movies_new['genre_new'][k])
  for j in movies_new['genre_new'][k]:
    list2=[]
    for i in range(aux.shape[0]):
      if str(aux[0][i]) == j:
        list2.append(aux.index[i])
    print("Possible genre for tag ",j," : ",list2)
  print('\n')
# Out:
# Movie:  Sathi
# Predicted genre:  [('69',)]
# Actual genre:  ['69', '13']
# Possible genre for tag  69  :  ['kafkaesque', 'dystopia', 'cyberpunk', 'future noir']
# Possible genre for tag  13  :  ['culture & society', 'documentary', 'social issues', 'gender issues', 'law & crime']
#
#
# Movie:  Badla Jatti Da
# Predicted genre:  [('13', '69')]
# Actual genre:  ['69', '4', '55']
# Possible genre for tag  69  :  ['kafkaesque', 'dystopia', 'cyberpunk', 'future noir']
# Possible genre for tag  4  :  ['gay themed', 'lgbt', 'gay interest', 'gay']
# Possible genre for tag  55  :  ['pornographic movie', 'erotic drama', 'pinku eiga', 'erotica']
#
#
# Movie:  Achanak
# Predicted genre:  [('13', '69')]
# Actual genre:  ['13']
# Possible genre for tag  13  :  ['culture & society', 'documentary', 'social issues', 'gender issues', 'law & crime']
#
#
# Movie:  Descent
# Predicted genre:  [()]
# Actual genre:  ['71', '22', '55', '4', '51']
# Possible genre for tag  71  :  ['detective fiction', 'detective']
# Possible genre for tag  22  :  ['cold war', 'nuclear warfare', 'therimin music', 'alien invasion']
# Possible genre for tag  55  :  ['pornographic movie', 'erotic drama', 'pinku eiga', 'erotica']
# Possible genre for tag  4  :  ['gay themed', 'lgbt', 'gay interest', 'gay']
# Possible genre for tag  51  :  ['comedy', 'romantic comedy', 'romantic drama', 'drama', 'romance film']
#
#
# Movie:  Diary of the Dead
# Predicted genre:  [('34', '85')]
# Actual genre:  ['71', '85', '51', '17', '34', '55']
# Possible genre for tag  71  :  ['detective fiction', 'detective']
# Possible genre for tag  85  :  ['suspense', 'mystery', 'thriller', 'crime thriller', 'crime fiction', 'psychological thriller']
# Possible genre for tag  51  :  ['comedy', 'romantic comedy', 'romantic drama', 'drama', 'romance film']
# Possible genre for tag  17  :  ['bloopers & candid camera', 'graphic & applied arts', 'extreme sports']
# Possible genre for tag  34  :  ['b-western', 'spaghetti western', 'western', 'comedy western', 'revisionist western']
# Possible genre for tag  55  :  ['pornographic movie', 'erotic drama', 'pinku eiga', 'erotica']
#
#
# Movie:  My Little Bride
# Predicted genre:  [('69', '89')]
# Actual genre:  ['69', '13']
# Possible genre for tag  69  :  ['kafkaesque', 'dystopia', 'cyberpunk', 'future noir']
# Possible genre for tag  13  :  ['culture & society', 'documentary', 'social issues', 'gender issues', 'law & crime']
#
#
# Movie:  For Love or Money
# Predicted genre:  [('69',)]
# Actual genre:  ['69']
# Possible genre for tag  69  :  ['kafkaesque', 'dystopia', 'cyberpunk', 'future noir']
#
#
# Movie:  Dont Look Back
# Predicted genre:  [('69',)]
# Actual genre:  ['17', '69', '31', '79']
# Possible genre for tag  17  :  ['bloopers & candid camera', 'graphic & applied arts', 'extreme sports']
# Possible genre for tag  69  :  ['kafkaesque', 'dystopia', 'cyberpunk', 'future noir']
# Possible genre for tag  31  :  ['interpersonal relationships', 'family & personal relationships']
# Possible genre for tag  79  :  ['musical', 'bollywood', 'world cinema']
#
#
# Movie:  The King of Kong: A Fistful of Quarters
# Predicted genre:  [('69',)]
# Actual genre:  ['68', '82', '79']
# Possible genre for tag  68  :  ['indie', 'black-and-white', 'silent film']
# Possible genre for tag  82  :  ['sponsored film', 'ninja movie', 'romantic thriller', 'feature film', 'road-horror', 'werewolf fiction', 'ealing comedies', 'statutory rape', 'fan film', 'malayalam cinema', 'mumblecore', 'czechoslovak new wave', 'war effort', 'psycho-biddy', 'chick flick', 'foreign legion', 'sci fi pictures original films', 'political documetary', 'film-opera', 'bruceploitation', 'buddy picture', 'revenge', 'haunted house film', 'revisionist fairy tale', 'prison escape', 'anthology', 'school story', 'comdedy', 'live action', 'coming-of-age film', 'fantasy drama', 'psychological horror', 'anthropology', 'historical documentaries', 'mondo film', 'filmed play']
# Possible genre for tag  79  :  ['musical', 'bollywood', 'world cinema']
#
#
# Movie:  The Bullfighters
# Predicted genre:  [('69',)]
# Actual genre:  ['0', '69']
# Possible genre for tag  0  :  ['stand-up comedy', 'concert film']
# Possible genre for tag  69  :  ['kafkaesque', 'dystopia', 'cyberpunk', 'future noir']

# %% [markdown]
# **KMeans Clustering predictions**

# %%
with open('parrot2.pkl', 'rb') as f:
  
  genlabel = pickle.load(f)

# %%
label,cluster = zip(*genlabel)
label=list(label)
print(label)
cluster=list(cluster)

print(len(cluster))
print(label[17])
# Out:
# ['b-western', 'stand-up comedy', 'natural disaster', 'boxing', 'crime', 'sword and sorcery films', 'period piece', 'horse racing', 'television movie', 'comedy-drama', 'gay themed', 'chase movie', 'pornographic movie', 'sponsored film', 'neorealism', 'whodunit', 'ninja movie', 'roadshow theatrical release', 'romantic thriller', 'costume adventure', 'gross out', 'feature film', 'plague', 'slasher', 'glamorized spy film', 'film & television history', 'road-horror', 'stop motion', 'werewolf fiction', 'news', 'tragedy', "children's fantasy", 'action', 'superhero movie', 'tokusatsu', 'culture & society', 'sword and sorcery', 'parody', 'indian western', 'sex comedy', 'media studies', 'religious film', 'star vehicle', 'sci-fi horror', 'essay film', 'bloopers & candid camera', 'adventure comedy', 'alien film', "children's entertainment", 'swashbuckler films', 'silhouette animation', 'kafkaesque', 'giallo', 'hagiography', "children's issues", 'graphic & applied arts', 'biker film', 'british new wave', 'comedy of errors', 'courtroom drama', 'concert film', 'animal picture', 'educational', 'musical drama', 'comedy', 'goat gland', 'domestic comedy', 'animated musical', 'ealing comedies', 'science fiction western', 'detective fiction', 'comedy of manners', 'surrealism', 'statutory rape', 'superhero', 'outlaw', 'christian film', 'archaeology', 'screwball comedy', 'disaster', 'fan film', 'slice of life story', 'cold war', 'martial arts film', 'comedy thriller', 'epic western', 'dogme 95', 'adult', 'extreme sports', 'musical comedy', 'malayalam cinema', 'biographical film', 'supernatural', 'punk rock', 'chinese movies', 'escape film', 'absurdism', 'acid western', 'parkour in popular culture', 'master criminal films', 'legal drama', 'family-oriented adventure', 'tollywood', 'roadshow/carny', 'mumblecore', 'black comedy', 'courtroom comedy', 'americana', 'spaghetti western', 'holiday film', 'period horror', 'beach film', 'romantic comedy', 'fantasy', 'dystopia', 'exploitation', 'homoeroticism', 'family drama', 'film noir', 'business', 'hip hop movies', 'political cinema', 'world history', 'gross-out film', 'cult', 'medical fiction', 'gothic film', 'remake', 'political drama', 'documentary', 'british empire film', 'interpersonal relationships', 'gay pornography', 'romantic drama', 'illnesses & disabilities', 'spy', 'western', 'sexploitation', 'nature', 'japanese movies', 'existentialism', 'conspiracy fiction', 'pornography', 'social issues', 'czechoslovak new wave', 'war effort', 'psycho-biddy', 'education', 'chick flick', 'movie serial', 'nuclear warfare', 'supermarionation', 'indie', 'anime', 'singing cowboy', 'lgbt', 'drama', 'albino bias', 'anti-war', 'erotic drama', 'horror comedy', 'foreign legion', 'history', 'short film', 'sci fi pictures original films', 'health & fitness', 'clay animation', 'stoner film', 'addiction drama', 'environmental science', 'biography', 'sci-fi adventure', 'political documetary', 'romantic fantasy', 'film-opera', 'mythological fantasy', 'fantasy adventure', 'bruceploitation', 'historical fiction', 'jukebox musical', 'inspirational drama', 'suspense', 'linguistics', 'propaganda film', 'film adaptation', 'prison', 'pre-code', 'war film', 'humour', 'filipino', 'comedy horror', 'camp', 'kitchen sink realism', 'mystery', 'libraries and librarians', 'gay interest', 'neo-noir', 'gay', 'journalism', 'adventure', 'crime comedy', 'beach party film', 'workplace comedy', 'teen', 'prison film', 'zombie film', 'action/adventure', 'childhood drama', 'race movie', 'steampunk', 'action thrillers', 'buddy picture', 'coming of age', 'revenge', 'buddy film', 'instrumental music', 'comedy western', 'black-and-white', 'computer animation', 'filipino movies', 'archives and records', 'patriotic film', 'northern', 'romance film', 'docudrama', 'creature film', 'caper story', 'haunted house film', 'tragicomedy', 'pinku eiga', 'reboot', 'erotica', 'music', 'outlaw biker film', 'monster', 'time travel', 'musical', 'horror', 'revisionist fai ...
# 363
# roadshow theatrical release

# %%
#Predicting and displaying tags for first 100 datasets in validation set
def infer_tags(q):
    q = clean_text(q)
    q = remove_stopwords(q)
    q_vec = tfidf_vectorizer.transform([q])
    q_pred = clf.predict(q_vec)
    return multilabel_binarizer.inverse_transform(q_pred)
  
  
for i in range(10): 
  k = xval.sample(1).index[0] 
  print("Movie: ", movies_new['movie_name'][k], "\nPredicted genre: ", infer_tags(xval[k])), print("Actual genre: ",movies_new['genre_new'][k])
  for j in movies_new['genre_new'][k]:
    list2=[]
    for k in range(363):
      if cluster[k] == j:
        list2.append(label[k])
    print("Possible genre for tag ",j," : ",list2)
  print('\n')
# Out:
# Movie:  Operation C.I.A.
# Predicted genre:  [(7, 10, 11)]
# Actual genre:  [11, 2, 10, 7]
# Possible genre for tag  11  :  ['road-horror', 'werewolf fiction', 'action', 'superhero movie', 'tokusatsu', 'sword and sorcery', 'sex comedy', 'concert film', 'ealing comedies', 'history', 'sci fi pictures original films', 'health & fitness', 'childhood drama', 'steampunk', 'coming of age', 'revenge', 'buddy film', 'instrumental music', 'comedy western', 'black-and-white', 'computer animation', 'filipino movies', 'archives and records', 'patriotic film', 'anti-war film', 'slapstick', 'fictional film', 'hardcore pornography', 'coming-of-age film']
# Possible genre for tag  11  :  ['road-horror', 'werewolf fiction', 'action', 'superhero movie', 'tokusatsu', 'sword and sorcery', 'sex comedy', 'concert film', 'ealing comedies', 'history', 'sci fi pictures original films', 'health & fitness', 'childhood drama', 'steampunk', 'coming of age', 'revenge', 'buddy film', 'instrumental music', 'comedy western', 'black-and-white', 'computer animation', 'filipino movies', 'archives and records', 'patriotic film', 'anti-war film', 'slapstick', 'fictional film', 'hardcore pornography', 'coming-of-age film']
# Possible genre for tag  7  :  ['parody', 'indian western', 'educational', 'musical drama', 'science fiction western', 'detective fiction', 'disaster', 'fan film', 'extreme sports', 'spy', 'conspiracy fiction', 'pornography', 'czechoslovak new wave', 'albino bias', 'anti-war', 'short film', 'addiction drama', 'biography', 'sci-fi adventure', 'film-opera', 'fantasy adventure', 'bruceploitation', 'historical fiction', 'jukebox musical', 'inspirational drama', 'linguistics', 'propaganda film', 'film adaptation', 'pre-code', 'war film', 'humour', 'filipino', 'comedy horror', 'camp', 'mystery', 'neo-noir', 'caper story', 'haunted house film', 'outlaw biker film', 'epic', 'therimin music', 'the netherlands in world war ii', 'road movie', 'alien invasion', 'heaven-can-wait fantasies', 'prison escape', 'social problem film', 'film', 'vampire movies', 'splatter film', 'comdedy', 'live action', 'b-movie', 'silent film', 'z movie', 'anthropology', 'crime drama', 'art film', 'political thriller', 'point of view shot', 'mondo film', 'psychological thriller']
#
#
# Movie:  Eun-Gyo
# Predicted genre:  [(10,)]
# Actual genre:  [10]
# Possible genre for tag  10  :  ['crime', 'gross out', 'feature film', 'plague', 'glamorized spy film', 'film & television history', 'graphic & applied arts', 'british new wave', 'comedy of errors', 'courtroom drama', 'period horror', 'beach film', 'medical fiction', 'documentary', 'romantic drama', 'sexploitation', 'social issues', 'chick flick', 'nuclear warfare', 'drama', 'erotic drama', 'horror comedy', 'political documetary', 'mythological fantasy', 'action/adventure', 'action thrillers', 'romance film', 'docudrama', 'creature film', 'tragicomedy', 'pinku eiga', 'reboot', 'erotica', 'music', 'monster', 'musical', 'mockumentary', 'space western', 'private military company', 'christmas movie', 'animated cartoon', 'sports', 'biopic [feature]', 'heavenly comedy']
#
#
# Movie:  Winnie the Pooh
# Predicted genre:  [(1, 2, 7, 8, 9)]
# Actual genre:  [1, 2, 8, 9, 10]
# Possible genre for tag  1  :  ['supermarionation', 'anime', 'romantic fantasy', 'time travel', 'inventions & innovations', 'heist', 'historical epic', "children's/family", 'combat films', 'comedy film']
# Possible genre for tag  2  :  ['media studies', 'religious film', 'star vehicle', 'sci-fi horror', 'essay film', 'bloopers & candid camera', 'alien film', "children's entertainment", 'silhouette animation', 'kafkaesque', 'hagiography', "children's issues", 'biker film', 'superhero', 'outlaw', 'christian film', 'screwball comedy', 'biographical film', 'holiday film', 'war effort', 'education', 'finance & investing', 'sci-fi thriller', 'wuxia', 'buddy cop', 'school story', 'operetta', 'family & personal relationships', 'thriller', 'baseball', 'fairy tale', 'costume drama', 'family film', 'science fiction', 'feminist film', 'bengali cinema', 'revisionist western', 'historical documentaries', 'sword and sandal', 'juvenile delinquency film']
# Possible genre for tag  8  :  ['slasher', 'martial arts film', 'comedy thriller', 'dogme 95', 'supernatural', 'prison film', 'zombie film', 'horror', 'revisionist fairy tale', 'fantasy comedy', 'expressionism', 'cavalry film', 'media satire', "children's", 'experimental film', 'melodrama', 'doomsday film', 'animation', 'gender issues', 'historical drama', 'travel', 'ensemble film', 'new hollywood', 'cyberpunk', 'computers', 'erotic thriller', 'new queer cinema', 'psychological horror']
# Possible genre for tag  9  :  ['stop motion', 'news', 'tragedy', "children's fantasy", 'culture & society', 'giallo', 'comedy', 'goat gland', 'domestic comedy', 'animated musical', 'comedy of manners', 'surrealism', 'statutory rape', 'epic western', 'musical comedy', 'malayalam cinema', 'punk rock', 'chinese movies', 'absurdism', 'acid western', 'master criminal films', 'legal drama', 'family-oriented adventure', 'tollywood', 'roadshow/carny', 'black comedy', 'courtroom comedy', 'spaghetti western', 'interpersonal relationships', 'japanese movies', 'psycho-biddy', 'movie serial', 'foreign legion', 'clay animation', 'environmental science', 'suspense', 'prison', 'kitchen sink realism', 'libraries and librarians', 'gay interest', 'gay', 'journalism', 'adventure', 'crime comedy', 'beach party film', 'workplace comedy', 'race movie', 'auto racing', 'costume horror', 'action comedy', 'anthology', 'tamil cinema', 'gulf war', 'early black cinema', 'marriage drama', 'dance', 'women in prison films', 'language & literature', 'apocalyptic and post-apocalyptic fiction']
# Possible genre for tag  10  :  ['crime', 'gross out', 'feature film', 'plague', 'glamorized spy film', 'film & television history', 'graphic & applied arts', 'british new wave', 'comedy of errors', 'courtroom drama', 'period horror', 'beach film', 'medical fiction', 'documentary', 'romantic drama', 'sexploitation', 'social issues', 'chick flick', 'nuclear warfare', 'drama', 'erotic drama', 'horror comedy', 'political documetary', 'mythological fantasy', 'action/adventure', 'action thrillers', 'romance film', 'docudrama', 'creature film', 'tragicomedy', 'pinku eiga', 'reboot', 'erotica', 'music', 'monster', 'musical', 'mockumentary', 'space western', 'private military company', 'christmas movie', 'animated cartoon', 'sports', 'biopic [feature]', 'heavenly comedy']
#
#
# Movie:  A Cry in the Night
# Predicted genre:  [(10,)]
# Actual genre:  [10, 2, 3, 6]
# Possible genre for tag  10  :  ['crime', 'gross out', 'feature film', 'plague', 'glamorized spy film', 'film & television history', 'graphic & applied arts', 'british new wave', 'comedy of errors', 'courtroom drama', 'period horror', 'beach film', 'medical fiction', 'documentary', 'romantic drama', 'sexploitation', 'social issues', 'chick flick', 'nuclear warfare', 'drama', 'erotic drama', 'horror comedy', 'political documetary', 'mythological fantasy', 'action/adventure', 'action thrillers', 'romance film', 'docudrama', 'creature film', 'tragicomedy', 'pinku eiga', 'reboot', 'erotica', 'music', 'monster', 'musical', 'mockumentary', 'space western', 'private military company', 'christmas movie', 'animated cartoon', 'sports', 'biopic [feature]', 'heavenly comedy']
# Possible genre for tag  2  :  ['media studies', 'religious film', 'star vehicle', 'sci-fi horror', 'essay film', 'bloopers & candid camera', 'alien film', "children's entertainment", 'silhouette animation', 'kafkaesque', 'hagiography', "children's issues", 'biker film', 'superhero', 'outlaw', 'christian film', 'screwball comedy', 'biographical film', 'holiday film', 'war effort', 'education', 'finance & investing', 'sci-fi thriller', 'wuxia', 'buddy cop', 'school story', 'operetta', 'family & personal relationships', 'thriller', 'baseball', 'fairy tale', 'costume drama', 'family film', 'science fiction', 'feminist film', 'bengali cinema', 'revisionist western', 'historical documentaries', 'sword and sandal', 'juvenile delinquency film']
# Possible genre for tag  3  :  ['natural disaster', 'boxing', 'television movie', 'adventure comedy', 'swashbuckler films', 'archaeology', 'slice of life story', 'cold war', 'adult', 'escape film', 'mumblecore', 'americana', 'political drama', 'existentialism', 'indie', 'singing cowboy', 'lgbt', 'stoner film', 'buddy picture', 'political satire', 'hybrid western', 'avant-garde', 'bollywood', 'rockumentary', 'airplanes and airports', 'fantasy drama', 'backstage musical', 'natural horror films', 'female buddy film', 'demonic child', 'satire', 'crime fiction', 'latino', 'world cinema']
# Possible genre for tag  6  :  ['parkour in popular culture', 'romantic comedy', 'fantasy', 'dystopia', 'exploitation', 'homoeroticism', 'family drama', 'film noir', 'business', 'hip hop movies', 'political cinema', 'world history', 'gross-out film', 'cult', 'gothic film', 'remake', 'british empire film', 'gay pornography', 'illnesses & disabilities', 'western', 'crime thriller']
#
#
# Movie:  The Help
# Predicted genre:  [(9, 10)]
# Actual genre:  [0, 10]
# Possible genre for tag  0  :  ['period piece', 'horse racing', 'comedy-drama', 'gay themed', 'chase movie', 'pornographic movie', 'sponsored film', 'neorealism', 'whodunit', 'ninja movie', 'roadshow theatrical release', 'romantic thriller', 'nature']
# Possible genre for tag  10  :  ['crime', 'gross out', 'feature film', 'plague', 'glamorized spy film', 'film & television history', 'graphic & applied arts', 'british new wave', 'comedy of errors', 'courtroom drama', 'period horror', 'beach film', 'medical fiction', 'documentary', 'romantic drama', 'sexploitation', 'social issues', 'chick flick', 'nuclear warfare', 'drama', 'erotic drama', 'horror comedy', 'political documetary', 'mythological fantasy', 'action/adventure', 'action thrillers', 'romance film', 'docudrama', 'creature film', 'tragicomedy', 'pinku eiga', 'reboot', 'erotica', 'music', 'monster', 'musical', 'mockumentary', 'space western', 'private military company', 'christmas movie', 'animated cartoon', 'sports', 'biopic [feature]', 'heavenly comedy']

# %% [markdown]
# **Basic model**

# %%
def infer_tags(q):
    q = clean_text(q)
    q = remove_stopwords(q)
    q_vec = tfidf_vectorizer.transform([q])
    q_pred = clf.predict(q_vec)
    return multilabel_binarizer.inverse_transform(q_pred)
  
  
for i in range(5): 
  k = xval.sample(1).index[0] 
  print("Movie: ", movies_new['movie_name'][k], "\nPredicted genre: ", infer_tags(xval[k])), print("Actual genre: ",movies_new['genre_new'][k], "\n")
# Out:
# Movie:  Aao Pyaar Karen
# Predicted genre:  [('drama', 'romance film', 'world cinema')]
# Actual genre:  ['romance film', 'drama']
#
# Movie:  Desperate Lives
# Predicted genre:  [('drama',)]
# Actual genre:  ['drama']
#
# Movie:  Twitches Too!
# Predicted genre:  [('comedy',)]
# Actual genre:  ['family film', 'comedy', 'teen', 'television movie']
#
# Movie:  Washington Square
# Predicted genre:  [('drama', 'romance film')]
# Actual genre:  ['romantic drama', 'period piece', 'drama', 'romance film', 'film adaptation']
#
# Movie:  Saving Shiloh
# Predicted genre:  [()]
# Actual genre:  ["children's/family", 'family drama', 'childhood drama', 'drama', 'coming of age', 'family film']
